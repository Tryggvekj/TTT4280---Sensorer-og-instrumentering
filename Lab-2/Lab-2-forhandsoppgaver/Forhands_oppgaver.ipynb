# %% [markdown]
# Forhandsoppgaver
# Oppg 1

# %%
import numpy as np
import scipy
import matplotlib.pyplot as plt

dt = 0.01 # delay til signalene

fs = 10000 
t = np.linspace(0, 1, fs)  

signal1 = np.sin(2 * np.pi * 10 * t) 
signal2 = np.sin(2 * np.pi * 10 * (t - dt))  

correlation = scipy.signal.correlate(signal1, signal2)
#print(len(correlation))
delay = (np.argmax(np.abs(correlation)) - len(signal1) + 1 )/ fs 
print(delay, "sekunder")
# Out:
# -0.0099 sekunder

# %% [markdown]
# Oppgave 2A
# $$ \Delta t = \frac{d}{V_{lyd}} $$
#
# max sample offset N
#
# $$ N = \Delta t f_s = \frac{d}{v_{lyd}}f_s $$
#
# Med d = 6.9e-2m
#
# $$N= \frac{6.9cm *32.5kHz}{340m/s}  = 6.59 $$

# %% [markdown]
# Oppgave 2B

# %% [markdown]
# Max delay på N=2
# betyr at vi kan ha 5 forskjellige delays: 2,1,0,-1,-2 -> max 5 vinkler inn
#
# Max delay på N=4
# betyr at vi kan ha 5 forskjellige delays: 4,3,2,1,0,-1,-2,-3,-4 -> max 5 vinkler inn
